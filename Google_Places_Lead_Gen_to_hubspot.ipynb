# %%
# %pip install requests pandas tqdm

import requests
import pandas as pd
from tqdm import tqdm
import time

# --- CONFIG ---
API_KEY = "AIzaSyBW12XVD4xOBHzHyxjm051U_jZppZs2gIs"  # 🔑 Replace this with your key
MAX_RESULTS = 150 # Set the maximum number of results you want to retrieve

# --- INPUTS ---
keyword = input("Enter business type (e.g. 'dentist', 'restaurant', 'marketing agency'): ")
location = input("Enter location (e.g. 'Ikeja Lagos', 'Abuja', 'Port Harcourt'): ")
radius = 10000  # meters

# --- PHASE 1: BASIC PLACE SEARCH WITH PAGINATION ---
search_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={keyword}+in+{location}&radius={radius}&key={API_KEY}"
all_places = []
next_page_token = None

while len(all_places) < MAX_RESULTS:
    if next_page_token:
        search_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken={next_page_token}&key={API_KEY}"
    elif all_places: # Only request first page once
      break # Exit loop if no next_page_token and not the first page


    response = requests.get(search_url)
    data = response.json()

    places = data.get("results", [])
    all_places.extend(places)
    print(f"✅ Found {len(places)} results in this page. Total results: {len(all_places)}")

    next_page_token = data.get("next_page_token")

    if not next_page_token or len(places) == 0:
        break
    time.sleep(2) # Add a delay to avoid rate limiting

print(f"✅ Finished collecting initial results. Total results: {len(all_places)}")

# --- PHASE 2: PLACE DETAILS ENRICHMENT ---
details_url = "https://maps.googleapis.com/maps/api/place/details/json"
enriched_data = []

# Limit the number of places to process based on MAX_RESULTS
places_to_process = all_places[:MAX_RESULTS]


for place in tqdm(places_to_process, desc="Enriching leads"):
    place_id = place.get("place_id")
    params = {
        "place_id": place_id,
        "fields": "name,formatted_address,formatted_phone_number,website,rating,opening_hours,geometry",
        "key": API_KEY
    }
    details_resp = requests.get(details_url, params=params).json()
    details = details_resp.get("result", {})

    enriched_data.append({
        "Name": details.get("name"),
        "Address": details.get("formatted_address"),
        "Phone": details.get("formatted_phone_number"),
        "Website": details.get("website"),
        "Rating": details.get("rating"),
        "Open_Now": details.get("opening_hours", {}).get("open_now") if details.get("opening_hours") else None,
        "Maps_URL": f"https://www.google.com/maps/place/?q=place_id:{place_id}",
        "Location": location # Add the location to the DataFrame
    })

df = pd.DataFrame(enriched_data)

# --- EXPORT ---
file_name = f"{keyword}_{location}_enriched_leads.csv".replace(" ", "_")
df.to_csv(file_name, index=False)

print(f"💾 Exported {len(df)} enriched leads to '{file_name}'")
# Out:
# Requirement already satisfied: requests in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ✅ Found 20 results in this page. Total results: 20
# ✅ Found 20 results in this page. Total results: 40
# ✅ Found 20 results in this page. Total results: 40
# ✅ Found 20 results in this page. Total results: 60
# ✅ Finished collecting initial results. Total results: 60
# ✅ Found 20 results in this page. Total results: 60
# ✅ Finished collecting initial results. Total results: 60
# Enriching leads: 100%|██████████| 60/60 [01:21<00:00,  1.35s/it]
# 💾 Exported 60 enriched leads to 'Car_dealership_Abuja_enriched_leads.csv'

# %%
import requests
import time
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv

# Load .env (if notebook restarted independently)
load_dotenv(r"c:\Users\DELL\Downloads\Revops Code\RevOps_Analytics_portfolio\.env")

# === HUBSPOT CONFIGURATION ===
HUBSPOT_API_KEY = os.getenv("HUBSPOT_API_KEY")  # loaded from .env
if not HUBSPOT_API_KEY:
    raise RuntimeError("HUBSPOT_API_KEY not found in environment. Add it to the .env file.")
BASE_URL = "https://api.hubapi.com"
COMPANY_URL = f"{BASE_URL}/crm/v3/objects/companies"

headers = {
    "Authorization": f"Bearer {HUBSPOT_API_KEY}",
    "Content-Type": "application/json"
}

# === FUNCTION: CHECK IF COMPANY EXISTS ===
def company_exists(domain=None, name=None):
    """Checks HubSpot for existing company by domain or name."""
    search_url = f"{BASE_URL}/crm/v3/objects/companies/search"
    filters = []

    if domain:
        filters.append({"propertyName": "domain", "operator": "EQ", "value": domain})
    if name and not domain:
        filters.append({"propertyName": "name", "operator": "EQ", "value": name})

    if not filters:
        return False

    payload = {"filterGroups": [{"filters": filters}]}
    resp = requests.post(search_url, headers=headers, json=payload)

    if resp.status_code != 200:
        print(f"⚠️ Search error for {name}: {resp.text}")
        return False

    results = resp.json().get("results", [])
    return len(results) > 0


# === FUNCTION: CREATE COMPANY ===
def create_company(row):
    """Creates company in HubSpot if not already existing."""
    if company_exists(domain=row["Website"], name=row["Name"]):
        return {"Name": row["Name"], "Status": "Duplicate", "Timestamp": datetime.now()}

    data = {
        "properties": {
            "name": row["Name"],
            "address": row["Address"],
            "phone": row["Phone"] or "",
            "domain": row["Website"] if row["Website"] else "",
            "city": row["Location"],
            # Removed the 'source' property as it caused an error
        }
    }

    response = requests.post(COMPANY_URL, headers=headers, json=data)

    if response.status_code == 201:
        print(f"✅ Added company: {row['Name']}")
        return {"Name": row["Name"], "Status": "Added", "Timestamp": datetime.now()}
    else:
        print(f"❌ Failed for {row['Name']}: {response.text}")
        return {"Name": row["Name"], "Status": "Failed", "Timestamp": datetime.now()}


# === LOOP THROUGH LEADS AND PUSH TO HUBSPOT ===
sync_log = []

for i, row in df.iterrows():
    result = create_company(row)
    sync_log.append(result)
    time.sleep(0.3)  # Prevent API rate limit issues

# === EXPORT SYNC LOG ===
log_df = pd.DataFrame(sync_log)
log_file_name = f"company_sync_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
log_df.to_csv(log_file_name, index=False)

print(f"📊 Sync Log saved as {log_file_name}")
# Out:
# ✅ Added company: BRIMS Autos
# ✅ Added company: Abuja best cars
# ✅ Added company: Abuja best cars
# ✅ Added company: Kefiano Autos
# ✅ Added company: Kefiano Autos
# ✅ Added company: ABUJACAR
# ✅ Added company: ABUJACAR
# ✅ Added company: Abuja Motors
# ✅ Added company: Abuja Motors
# ✅ Added company: U.S. MATASA MOTORS ABUJA
# ✅ Added company: U.S. MATASA MOTORS ABUJA
# ✅ Added company: Abuja Cars Online
# ✅ Added company: Abuja Cars Online
# ✅ Added company: Abuja Car Stand
# ✅ Added company: Abuja Car Stand
# ✅ Added company: Barbedos Cars Ltd
# ✅ Added company: Barbedos Cars Ltd
# ✅ Added company: Kabuwol Motors Abuja
# ✅ Added company: Kabuwol Motors Abuja
# ✅ Added company: Abuja Auto Cars
# ✅ Added company: Abuja Auto Cars
# ✅ Added company: KAKANDA AUTOMOBILE LIMITED
# ✅ Added company: KAKANDA AUTOMOBILE LIMITED
# ✅ Added company: Abuja Used Cars
# ✅ Added company: Abuja Used Cars
# ✅ Added company: Coscharis Motors Plc, ABUJA
# ✅ Added company: Coscharis Motors Plc, ABUJA
# ✅ Added company: Buy Abuja Cars
# ✅ Added company: Buy Abuja Cars
# ✅ Added company: BestAutos
# ✅ Added company: BestAutos
# ✅ Added company: Abuja Car Limited
# ✅ Added company: Abuja Car Limited
# ✅ Added company: SarkinMota Autos
# ✅ Added company: SarkinMota Autos
# ✅ Added company: Gazabagarage
# ✅ Added company: Gazabagarage
# ✅ Added company: Affordable cars Abuja
# ✅ Added company: Affordable cars Abuja
# ✅ Added company: Casa Del Noblez Auto
# ✅ Added company: Casa Del Noblez Auto
# ✅ Added company: Kia Motors Nigeria Showroom + Service Centre, Abuja
# ✅ Added company: Kia Motors Nigeria Showroom + Service Centre, Abuja
# ✅ Added company: ELIZADE NIGERIA LIMITED
# ✅ Added company: ELIZADE NIGERIA LIMITED
# ✅ Added company: Deals on Wheels
# ✅ Added company: Deals on Wheels
# ✅ Added company: Imkash Automobiles
# ✅ Added company: Imkash Automobiles
# ✅ Added company: Lanre Shittu Motors
# ✅ Added company: Lanre Shittu Motors
# ✅ Added company: I-SQUARE AUTOS LTD
# ✅ Added company: I-SQUARE AUTOS LTD
# ✅ Added company: Abuja Cars Hub
# ✅ Added company: Abuja Cars Hub
# ✅ Added company: Stallion Motors
# ✅ Added company: Stallion Motors
# ✅ Added company: 180 Autos
# ✅ Added company: 180 Autos
# ✅ Added company: Boanerges Global Motors LTD - The Best Car dealer in Abuja
# ✅ Added company: Boanerges Global Motors LTD - The Best Car dealer in Abuja
# ✅ Added company: 99 Autos Cars for Sale
# ✅ Added company: 99 Autos Cars for Sale
# ✅ Added company: Abuja star car / white burj group
# ✅ Added company: Abuja star car / white burj group
# ✅ Added company: Dana Motors Ltd
# ✅ Added company: Dana Motors Ltd
# ✅ Added company: Miyetti Automobiles
# ✅ Added company: Miyetti Automobiles
# ✅ Added company: CFAO Mobility Abuja Branch
# ✅ Added company: CFAO Mobility Abuja Branch
# ✅ Added company: Done-credible Car Dealers Abuja
# ✅ Added company: Done-credible Car Dealers Abuja
# ✅ Added company: Kia Motors Servicing Jabi/Utako
# ✅ Added company: Kia Motors Servicing Jabi/Utako
# ✅ Added company: CarShop Abuja
# ✅ Added company: CarShop Abuja
# ✅ Added company: Omoregie Motors
# ✅ Added company: Omoregie Motors
# ✅ Added company: Cars for sale in Abuja
# ✅ Added company: Cars for sale in Abuja
# ✅ Added company: 80automobiles Car Dealership Abuja
# ✅ Added company: 80automobiles Car Dealership Abuja
# ✅ Added company: DRE LUXURY CARS
# ✅ Added company: DRE LUXURY CARS
# ✅ Added company: OJ Autos Global Nigeria Limited
# ✅ Added company: OJ Autos Global Nigeria Limited
# ✅ Added company: MBS AUTOS
# ✅ Added company: MBS AUTOS
# ✅ Added company: Galadima Auto
# ✅ Added company: Galadima Auto
# ✅ Added company: khairAutos
# ✅ Added company: khairAutos
# ✅ Added company: Royal autos nigeria
# ✅ Added company: Royal autos nigeria
# ✅ Added company: BANKROL CAMEL EV
# ✅ Added company: BANKROL CAMEL EV
# ✅ Added company: Capital Cars
# ✅ Added company: Capital Cars
# ✅ Added company: Boscy Autos
# ✅ Added company: Boscy Autos
# ✅ Added company: SKYEWISE GROUP
# ✅ Added company: SKYEWISE GROUP
# ✅ Added company: Exquisite Exotic Autos Limited
# ✅ Added company: Exquisite Exotic Autos Limited
# ✅ Added company: Bills And Mills Merchandise Limited
# ✅ Added company: Bills And Mills Merchandise Limited
# ✅ Added company: Celebrity Automobile And Merchandise LTD
# ✅ Added company: Celebrity Automobile And Merchandise LTD
# ✅ Added company: Cityline Autos Abuja
# ✅ Added company: Cityline Autos Abuja
# ✅ Added company: Razaq Autos Abuja
# ✅ Added company: Razaq Autos Abuja
# ✅ Added company: MKM AUTOS NIG LIMITED
# ✅ Added company: MKM AUTOS NIG LIMITED
# ✅ Added company: COSCHARIS GROUP LIMITED
# ✅ Added company: COSCHARIS GROUP LIMITED
# ✅ Added company: The Honda Place
# ✅ Added company: The Honda Place
# 📊 Sync Log saved as company_sync_log_20251026_155123.csv
# 📊 Sync Log saved as company_sync_log_20251026_155123.csv

# %%
print(response.status_code, response.text)
# Out:
# 200 {
#    "html_attributions" : [],
#    "results" :
#    [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "20 Durban St, Wuse 2, Abuja 900288, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.070275900000002,
#                "lng" : 7.4861514
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.071499829892721,
#                   "lng" : 7.48743957989272
#                },
#                "southwest" :
#                {
#                   "lat" : 9.068800170107277,
#                   "lng" : 7.484739920107276
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Skin Therapy Beauty and Spa Abuja",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 719,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101036102213702395450\"\u003eSkin Therapy Beauty and Spa Abuja\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6c50te22IXrI4AXqMw4-ylO2Gt1BUaqyZEcP0-nDGDcrCaWqYq_mqowXdyRp1Qlc7hr-hfYKaqGrUxMT_VqINVOJRvHun4YdwIjwVhLZ0-7LsuyKo1BBv2MnnUyR1hzK1hDD5gBsvKsPdjG-RSxTxIGkKdNzD8Qns8Tv7EWWobMKuHnzYVJpBDjuO9ICoNfifeOdsy06qP1zgeiK8WhMODBlPsE2Yr7bWxrez13eW_zacpkdD6PdyMlDeeBGaJO-CP9hxi-OomjdEFaq1t6FOiBTVY3x9WSewOg6qChACqvI5ezME",
#                "width" : 1080
#             }
#          ],
#          "place_id" : "ChIJjQshq-gKThARid2mFQc0FVc",
#          "rating" : 4.7,
#          "reference" : "ChIJjQshq-gKThARid2mFQc0FVc",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "hair_care",
#             "store",
#             "health",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 297
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "3 Goba, Wuse 2, Abuja 900288, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0830228,
#                "lng" : 7.469658799999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.084341029892721,
#                   "lng" : 7.47103237989272
#                },
#                "southwest" :
#                {
#                   "lat" : 9.081641370107278,
#                   "lng" : 7.468332720107276
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Spaholic Luxury",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 444,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114852541508922825868\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6QKnNfAsZLisGFacEUat-KFh-ThgnlH5ehgHcYu6gzsQ_6qQOMFZcOTL3Zhm_QJZ-rT4Lsvt9EoCWbWUGsiRboX4S-QAjwsP8xezP9g5GNMKUswb4FIpdZVMk-RPGhhpNIzz0KhhTZqw8y5i0pmaeIeW2txoub6fniVzUZ2yWpPMl-hW0PIlHrW0xEtPZernHSRe_oBRALQtMqYjpQFKd9dnpuyte_aDjp0Crw5PAIa72fwtG3ire8oLZal2VdOQl6KhBCbD2Ac4lhn-HJMFKE1MiFipt9sgFATvrlNn7YC7Ctmps",
#                "width" : 666
#             }
#          ],
#          "place_id" : "ChIJM_bulu0LThAR0A_ZBYq1uBY",
#          "rating" : 4.3,
#          "reference" : "ChIJM_bulu0LThAR0A_ZBYq1uBY",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "hair_care",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 49
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "no: 5 Birao St, IMac, Abuja 900103, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0719279,
#                "lng" : 7.4794298
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.073219279892724,
#                   "lng" : 7.480837029892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.07051962010728,
#                   "lng" : 7.478137370107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "DE\"_DOCTOR _HAIRSALOON AND SPA 💆‍♀️💆",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 4032,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106551733081564010932\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6lXeyoLJcVGNTz6bbvDt5GSqnnqVSZ7IqIHogPBUJQTvdBhnkiBgfdE7hXoWIR93ew3bSY1Q3UiJjNDu6U3r-vjyYksbUJuk53UtI6uQZ_t5YmMcjx94jTGuuN5o6nvjsdNOwhswFDJb2jCRL9vYcyLJX01DrpZed9Yl5Y9eROrsWqUmnF-2_js6kGL2j69emtolCXsbJMyBnTMeZ8M-1LEIxikItK-bxrmMZE3GgMAZAmBu6d7Xy_U-bomqA99pQEWJyXlgiimJHaG_Ln9fjQthywggOo2j3NRH41RuXG_LRaBdP-sCFB1AieoE-2KvGZTEIJyZx8Zb_0uPGr_vGT-mleZ7MmE7pEVPofWfKwbm4muh4QZA_VqrAsXChs2m5VrtIEFTlQrJukrtG-4t3HqXYh3JRjvk318C3NoG0dkRUK0GLZtC92qG70cLYViSMnACbsb3EoksvoN5BbKEm1jvHjU_LHlSzsbhaUSuIYCmoa650_UUlhSsahPxXDJJgOqhsjjIKWwNgijyKZEd9y0IHixhUqP7TuhXOh7YV8vQVUU1JVGbZbyNIFfzXvHcgpUqq1",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJy-io02gLThAROUfdCCaYjjQ",
#          "rating" : 5,
#          "reference" : "ChIJy-io02gLThAROUfdCCaYjjQ",
#          "types" :
#          [
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 19
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Off Idris Gigado St, Plot 707 Cassava St, Ankuru 900104, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0494082,
#                "lng" : 7.446969299999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.05064422989272,
#                   "lng" : 7.448228229892721
#                },
#                "southwest" :
#                {
#                   "lat" : 9.047944570107276,
#                   "lng" : 7.445528570107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Beauty Addict",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 6638,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105238762835272817705\"\u003eBeauty Addict\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7X20aJNeIBnM8gv9kwTX3b_I95gfjCbClbVvXJgGzUfsoBJFluGEs_n-eMg0Wmp9Q_xlyutSyew_1luO0OAdz483fHV9RYFiLU48A5j1fJmuCCfnILvgRpVZxXvd7Rh_NjdELAmEE-nqkV8BvvaCIb8j_ez1g2rqCWNqOEwFfXVt0oMxRIqynyzXfjU7jVQKWSmJuGW-JzxzwWhSORDb2-GAEpI9VTJkpkj_pmj_NP-X-cqLHPDgo5LXkAylpiI7VksWYriM7Yz36CewagZzng2kuOXojywVK3_lz3q34tg4hT",
#                "width" : 4430
#             }
#          ],
#          "place_id" : "ChIJ9_7VtzcLThARU-4t915olTY",
#          "rating" : 4.5,
#          "reference" : "ChIJ9_7VtzcLThARU-4t915olTY",
#          "types" :
#          [
#             "beauty_salon",
#             "health",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 213
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "13 fez street off Kumasi crescent, Aminu Kano Cres, Wuse 2, Abuja 900288, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.082305999999999,
#                "lng" : 7.479245199999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.083604879892722,
#                   "lng" : 7.480546279892721
#                },
#                "southwest" :
#                {
#                   "lat" : 9.080905220107278,
#                   "lng" : 7.477846620107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Guru’s Nest Aesthetics and spa",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1758,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117286318116756535685\"\u003eOjay Ajaifia\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU5_T_qDHHuQYktXGlaHb8YVGmvbpBjVJBIiZpiKM1bnlZnYZkjc-fbqFfeiEMz_pmH72-Kt7Smr1ZN4-jvJNIwvgmWxCu5b1vZsUXurQMVCOz37zBMepLWU_jZileFraP6mWBu0PG7LPj23vuS0-FNuVGvzlz7Q0L1SrTVNT8CpCeGpvCDhCoWNJNCdJ7XoXl0-oqUX3RhwrZWFryovfYHgI56nKW8_iNV5d_seQmLeoe2HsaGPgV-4YKchlzLBzGLFTA4clPKIrs1lsBqLc6DPlJ1ovi5PbO4E53AEjmGF-VIhlgb5C_2bmlzKaEPd5T5eLlS4KkrLn5LSPVEcDl15PWGcGVgMjcPLbtV6i8AeLb19_0-POrKft70LPVoKtTsT4ABK7SpHtWwSsWpPLDpEJ9hqQpBmf3xVltk2AUyn1pMaaV-kXZlH5zwQvQBnzqoRHt5M3fVqi3eeUr3D07vA-C-cMFcXKCBaGaaL2pGgKCW8akaS5gKtMEgThV70CqDcVrehT000zw_jyiZXV0SPGHnbJn3z75Y2Kzbocc4j3K0jBhftLjxT7ZwlE6y2BhDGEg",
#                "width" : 1240
#             }
#          ],
#          "place_id" : "ChIJYTsHXyoLThARzYzkju3bHKY",
#          "rating" : 4.8,
#          "reference" : "ChIJYTsHXyoLThARzYzkju3bHKY",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "health",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 85
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "72 B, Aminu Kano Cres, Wuse, Abuja 11, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.075708499999999,
#                "lng" : 7.463444399999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.077142729892724,
#                   "lng" : 7.464855929892724
#                },
#                "southwest" :
#                {
#                   "lat" : 9.07444307010728,
#                   "lng" : 7.46215627010728
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Hartland Beauty Salon",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1920,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/109347456352702015236\"\u003eHartland Beauty Salon\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7m89vB5AnADY8egHDhEbX4nN1nlqWEzxtPJXiFAeR9nWUImeUPspWAnYoG6dRSQWyC9uBn_i51V4qQuOybwlaJV9sB0w_9QhTAAO7adueH6a8BRbST6VjSlcGrjvzNXJ5ZhaUyW24GhGPshdiaRkemqGba4DvYTAg0eM_Yogt9b2OEtGunbGXVGKNhwJo0k35Zy9RslD9LG-93-jidYR9wYji3hbuWunmuocPSz5llAQbFCDgAV5gTLEqAIFOWpxHfjdVsGO7pOevCi4Py-1vO1MmkIWou73Ub2__oH7OhIjfXvqA",
#                "width" : 2560
#             }
#          ],
#          "place_id" : "ChIJS0Dox-YKThARBF6XJnNIOaA",
#          "rating" : 4.5,
#          "reference" : "ChIJS0Dox-YKThARBF6XJnNIOaA",
#          "types" :
#          [
#             "beauty_salon",
#             "store",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 78
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Plott 44, Bol Pharmgate Plaza, Gana Street, Maitama, Maitama, Abuja, Federal Capital Territory 904101, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.077792799999999,
#                "lng" : 7.499598199999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.079057329892722,
#                   "lng" : 7.50102132989272
#                },
#                "southwest" :
#                {
#                   "lat" : 9.076357670107278,
#                   "lng" : 7.498321670107276
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Mayfair Collections & Salon",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 3024,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/115856845642935403613\"\u003eMayfair Salon\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7DmMQvFwtnbUYG0O4hwDHbVTaW2Qwm3NUvaZH0pJTqQv-DQR1eXE0r3XABYAcL99o7ZcadjbkcjwUEDKHBeIJCj2uZS7hL_Hp4uSye41eLoq9XKh4J7WpkbY2xpkuLIVt3VxXgah_xkJaEex_qZRxceWZ-elj8E0aZUhTOaN3LCkeGrvU8axesRTZMVHrMgvy10hLnXYcUma4kJjVUc8G_QMIGbRQ-pRS_BC_57bZhqUesQbaF9eYg5BcLKeopMKSw2IRJRr_VV-PDlftAo_D8IQXNF-wTJ7xpC-o6lTGYMXbuFlNtbIgxHhDqMVCmx4NKrG49OVrutKxCqLbqFczLNNfSfklY8t05qL0bgp1y2VsKzBGUKYnPIQre-nEpipdfwyLsuFzNM6nHNVXYUbkx9Z5Q1SRBaehe8BRoy0g8q4ZmIoBdUNuDPDE1b8rmLRHBUzUJrXqGo6Mr5l1yaG-h1wL8oNWDaUmVosIIqiunEyGeYwL1pifq3mXB0xoG_kxDvFfKrsCGXEU7siiypKSbJE3DA-_4u7j4Ly7gpyZNjbWH2AsMlulXSY24pkuKowOcyg",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJqXlK7kgKThARRn3IMjYh6NY",
#          "rating" : 4.4,
#          "reference" : "ChIJqXlK7kgKThARRn3IMjYh6NY",
#          "types" :
#          [
#             "beauty_salon",
#             "store",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 38
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Birnin Kebbi Cres, Garki, Abuja 900103, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0234883,
#                "lng" : 7.483185599999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.024790629892722,
#                   "lng" : 7.484578529892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.022090970107278,
#                   "lng" : 7.481878870107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Queens Drive Spa I Salon I Aesthetics | Waxing, Laser, Eyelash, Eyebrow, Nails, Waxing, Massage, Facials, Steam etc",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 4032,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111485401810150491544\"\u003esarah A Okodugha\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU733f0GolFsdT3flHT1EKs7_vQQaCD62ljOYKY_5YqGZDrfYOJ4fghjyfK8coSS20egBjSkevBjBCGIrYNXxfWZQSxJJBRnWpDZvqVn_vMz8bRD_wzt2QDVon9C4sGqbOIWuGf7ntUx5OuWinnENZRyFzTvXOAZItinaXRFBd-hjOLA9fkLCv-bqKDxLtk2h010kEHXtbby30XAUZahs7FLsavrk3XDaoZp1fN7TP8GdjPtknxQWvh_C_rTg94u93mKg5MMxUJKDF4UdH9N0ynwmbPYlWt-fSSKSSmApSFMrI-_5Jjb_xfppPuq3iZwt2NdW4Aovi5CqKiGJ_0XgvvFib_qICNZlDIojOYccx8fjccW27IdHUye_1-4tlDuwFpjo7Qls0S1uC_KoA-P4jn84ETtjCSV0bRLA54N3vhGZ52gbTmx6vR6cwV0gKHKJJWSQOqmvTYhRw5LZxnWkUxee-h_Kj8gTUF1fbwBoUgOTpQBal7qzsVZBcZfhdgJUP3OAg1OytWkIwkMyQHxr0pIUcGbhAMcQQNmkwEkxsKmskXk6gcSO0J2f1nwPVn2tqGV0EtuiQDadZAs20jXj9DFfSiNrA",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJL6qMSbEPThARGWxXduAz3Ts",
#          "rating" : 5,
#          "reference" : "ChIJL6qMSbEPThARGWxXduAz3Ts",
#          "types" :
#          [
#             "beauty_salon",
#             "spa",
#             "hair_care",
#             "store",
#             "health",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 32
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "3FGG+MR9, 2 Adetokunbo Ademola Cres, Wuse, Abuja 904101, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0766794,
#                "lng" : 7.4771333
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.077999179892721,
#                   "lng" : 7.47853102989272
#                },
#                "southwest" :
#                {
#                   "lat" : 9.075299520107277,
#                   "lng" : 7.475831370107276
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Abuja polygel Wizzypronails",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 952,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117168527093103977924\"\u003eAbuja polygel Wizzypronails\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6UHvTD0je3jIDBUuHTnIOMcMddS3BXWAMwKmHJ1yhxticGKBCPzOEQpwi5Ge25ZDP7deSOvp4DIabCgH4GlyWTRygjpId5JbjsATSk-H5MDljYCPiGUn8M-5umC4Z27D-TM-pr4t3UX5dKado-pIKQrDdDwFjf1kzpyAWbg9jY_CICcKgv16hX0eQUc3SrCk6q9q8dmJYXXXhn2PyyL2SKz8xnRd5MT-njaGdwqb_Oee7Ecq-qu4V5jg-5vzhoCiWTwB0CH3ITD0SS6mNdwsoeFLj1E7Be9WcjTpVVCjMe2n952AY",
#                "width" : 1242
#             }
#          ],
#          "place_id" : "ChIJgW2VmAQLThARkalDt-jLjCA",
#          "rating" : 4.8,
#          "reference" : "ChIJgW2VmAQLThARkalDt-jLjCA",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 80
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Zone 1, No 29 Arusha Cres, Wuse, Wupa 904101, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.050889,
#                "lng" : 7.4633572
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.052240479892721,
#                   "lng" : 7.464756879892721
#                },
#                "southwest" :
#                {
#                   "lat" : 9.049540820107277,
#                   "lng" : 7.462057220107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "OMA NATURAL HAIR SALON WUSE",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 4032,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/117286318116756535685\"\u003eOjay Ajaifia\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7Io85bjeRH1z5N5LwoZLbCLVSqHGX3lHHQAABKHuxsH9QrcQYJso7ikOFN4Fsu4SXZ02QxI_hO6zIWVs4LfuEKiPHyB2XiPc6H8sx2d7bWGxhGYDhZ_-kzHe9ZiZ2BFVSftixXOePP70E-ltPcxQigqisC5Fr-QHWjY_oNxBiU6TQLzu7zIHoiER6BKeT0LM4qeNiCxfjNotWcBtUznmneYjjhcyejrjNmboMUF-qzlMXn8iqHI_NcwlR5m_evyAQeHQCKUOFHRd7o-MNyIHJIaSajBauTB1nJM9M22R5-GXln5i7ubTIPPpo7h-F4yD9SfHeBvkMvjMMZiaKFOWkq9Dau-l7v0zrsHSK0nMUBThlg_T7hwbPIk-PPoG0cCWZvwzQojDwrs_5c-fQdSxgw4NSOYr51ZuL8noe5d9ENKH1qCsoBclse7Rx0k083IC8QVUu_LjauXODH-jRPDPiVxRW9b1CbMJQIQaN_eEfF9ZKm7pcaTu__u0t4id61cX1QFDdlMS-iEye_48H2wouCk9e70_qkjcVJkN1Q4_SAYxrqEoItGXncaK2uWt64CJFHmDnGeQTqQQ",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJO25lvGgLThARhdvDCS-7p8w",
#          "rating" : 4.5,
#          "reference" : "ChIJO25lvGgLThARhdvDCS-7p8w",
#          "types" :
#          [
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 354
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "7B Konoko Cres, Street, Abuja 900288, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0728437,
#                "lng" : 7.474890200000001
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.074171779892723,
#                   "lng" : 7.476166679892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.071472120107279,
#                   "lng" : 7.473467020107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Chatoyer Beauty Lounge and Spa",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 2155,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116245877202549202874\"\u003eChatoyer Beauty Lounge and Spa\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6zUQfTmNvmEQuEiFTtLc29wVxxYWwQJyaVBYC2-Htaa5wDWG1mkLHYQ5qxC7KrnLFnfh5yMgEnMnCDRKEA45QZh8Ix8JywPrFQmecUTW4O19j6iWrqI3zzanxGUjvqEsFdOrNyhEII1TQZT5xV3jXZlEXQ_tWIdQSApJvhPVX4opyxiXKKIKw8UngHP9P3_1rmeggpymM2OGFL5yKn3oaVhwkCUUEH3oB9bDp1_Z7IKY2kXWoOghmAe1qkOfIS0Yeapo82UI_Dn_x_MWuOKbzH6GNX2NPJiZnItG0ovRGzhhn4lgA",
#                "width" : 3000
#             }
#          ],
#          "place_id" : "ChIJ5V5ZOPwKThARTaeYOc7kdU8",
#          "rating" : 4.4,
#          "reference" : "ChIJ5V5ZOPwKThARTaeYOc7kdU8",
#          "types" :
#          [
#             "beauty_salon",
#             "spa",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 101
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "8 Anambra Cres, off Nile Street, Maitama, Abuja 900271, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.096231099999999,
#                "lng" : 7.4893426
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.097490979892722,
#                   "lng" : 7.490697279892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.094791320107278,
#                   "lng" : 7.487997620107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Amaryadotcom Spa and Salon",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 3024,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105177159917915446151\"\u003eOtori ayeeshat\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU5OjN44irh34VUepHk2kgwE2PPIcqtXX-NEgZ7YE4HL7e69HU5EkEWdtrHhVMvT0aKCU_9f3HahsQbiP1a03xYMvNdWsW-BrODLBQvxakE0gfV8qfIAp_LISR-y4h6naZoJw1o56lTmsfJT_NodE36jMv6_V9gZJNippZcFBkn_6wAIV8mLg7zWEmhj6okT1tIOhShw2W032PftG4hy9B5MIL8TmFgfgNgBMFtr5A_9UKxDnTHJG4NFHoMP5cfGGIR0nRaDqciLy_pfes4aic9uV0KFR-67zrTedViakv7I9d0SeAASVgobXLimyLKzb3aQtxhUZ_rS5nQaUGzt0IAvts9E8-KMmhQPzRE0WQCCvVlVGpDNaXNjY0GExHs2BmKMbJ_OYa2lS9Vz_wtb5Ynr0ZAgwEyMesH-WZ3u7mnu2r7FNQqdVQM2yMGbtAF66qPsS_GzJzlyx4UmYnX_sgKnfXGR2Zyv1rxSoO8nllIVWH_qRERBveAeaPsuU1hqCQ533KAEqiYaAWUE21TE9JRt-ryLkibx07HOHBfSmMevigPCETR-gR7rf4nLMqczdb-HnOcc",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJ_fO0mowLThARTWGL4ihAKb0",
#          "rating" : 4.7,
#          "reference" : "ChIJ_fO0mowLThARTWGL4ihAKb0",
#          "types" :
#          [
#             "beauty_salon",
#             "gym",
#             "health",
#             "point_of_interest",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 88
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "5 Tillaberry close Off Kumasi Crescent, Off Aminu Kano Cres, Abuja, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.078831599999999,
#                "lng" : 7.4771723
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.080267929892722,
#                   "lng" : 7.478488829892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.077568270107278,
#                   "lng" : 7.475789170107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Mellon Traditional Spa and Salon",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 724,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/104447998997000903740\"\u003eMellon Traditional Spa and Salon\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU5o2mmwsreiIYScaFETCv7CGHd8Ns4nVq9MXLpVYqDZfSh-kBj2M8sxZZ-nidE_R1tKPMxDA6qK7UZlyMlMtAmEIOY8Tv5op3GiwN86BC4UGKFs7pQtR4CwtcudewrT3H60fwd6D1aNIjRgMadvj4xfq2nPtpcIPhNl0_PLO5_NI8GVPulTFsy5jPCq3vMk6BncEJX2aCWFgcgPsuqJ11Jt24hCQhvn4LYRkuZt0UQidox0sEI04h9-dcEv7q68HSoLkmtVaDQxkw7zbaFudFpGnY8LurQ8qn0Wjpq9opJdphO4TXU",
#                "width" : 1085
#             }
#          ],
#          "place_id" : "ChIJPzzWbwYLThAR14CCXocEnis",
#          "rating" : 4.7,
#          "reference" : "ChIJPzzWbwYLThAR14CCXocEnis",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 21
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "1 Kampala St, Wuse, Abuja 904101, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0786017,
#                "lng" : 7.4802427
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.079894529892723,
#                   "lng" : 7.481525029892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.077194870107279,
#                   "lng" : 7.478825370107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Nifty Cuts and Spa",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1728,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/107330668696283755172\"\u003eNifty Cuts and Spa\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU65UPmb4FI37sFSmP_UXaKF1CEu6mm1XTVL1YyqwU-tYqjPoJGHOL1Kkro72YwMI-okg7yzIh3M63BHoPYF5wcN-iCARE5IvcZWNiJAD7KkV6CUg9C9BLZzhaqeTm2tC_qp12S-cP0APIVC-c-SxVsu03I4tStPBric_C7BHDAs5mIUWzMKYlS-mKK4DUpoG1xf0nm4cdBkTdVlxJ3zbgmcqsfSdAOGQLKz4UPFwjmPGCZQo1mlNV7zlQy9Kxi-pCcOD7CUU9KiyyHKwuStV9m2OFC3rHhDGHG7h7GB3Gg0CldIqq8",
#                "width" : 3072
#             }
#          ],
#          "place_id" : "ChIJfUwPi4kLThAR6JRvyY2wC5o",
#          "rating" : 4.4,
#          "reference" : "ChIJfUwPi4kLThAR6JRvyY2wC5o",
#          "types" :
#          [
#             "spa",
#             "hair_care",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 78
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "37 Agadez Cres, Wuse, Abuja 904101, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0711818,
#                "lng" : 7.4713286
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.072627879892721,
#                   "lng" : 7.472682229892722
#                },
#                "southwest" :
#                {
#                   "lat" : 9.069928220107277,
#                   "lng" : 7.469982570107279
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "PHI NATURAL HAIR SALON",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1280,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103072620679473575358\"\u003ePHI NATURAL HAIR SALON\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU67a4UO-KDX0ntd8bfiHGwmWLBoF_tKTKwikA_sLb4uW8qlrznnQ56os8jW2kc95-RawDPVzdshCwH8J4kpNbJvSeoHGj1yOYuP8w8ZyKjAowztiq35xLgmO3lpxwWYHvWXOo2dvSIDgiBq1KHeXYweotHj1cgGKsT0NN6LdCcSFyunD9WpNQMMyzVznOVV5IWUwfpreT_gRXuzmSnMzkTxh0HcR48tmxUuWnE1bUeLXg9KuxZwFSSsroqJTVvUNA8DIYhdfhT7lMnmqaFC6n4okCe-UId9sXDp53Ocp2ORAreTo4o",
#                "width" : 576
#             }
#          ],
#          "place_id" : "ChIJCYFFoYoLThAROu3TDVYNjPg",
#          "rating" : 4.8,
#          "reference" : "ChIJCYFFoYoLThAROu3TDVYNjPg",
#          "types" :
#          [
#             "beauty_salon",
#             "hair_care",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 28
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "block b c, v.s, Plot 145 Adetokunbo Ademola Cres, Wuse, Abuja 900288, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.079589,
#                "lng" : 7.4805161
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.080940729892722,
#                   "lng" : 7.481869429892721
#                },
#                "southwest" :
#                {
#                   "lat" : 9.078241070107278,
#                   "lng" : 7.479169770107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Gnailz nail salon and",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1053,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103693850542054919025\"\u003eGnailz nail salon and\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU4kUPTRa18CPH1T5vvsScG4Ko0fyNgasavkYlGn2uciejkOylzPx_5BZzP-44iBBFOYpDIr2vFkgKHxq6gJQFtp_5TcCuqk2JT-xzPbG4DXrd_K7VFHPgFZXG6CzXD_e02jBU-SSG-izBZOiOdVB0Xa_NW5z5jHKWeVBmcl77E1q7yG3F6MB6LB3ozE7DAuR3yALprEMFv3Tz_ofAJu5NQDCaz5jh7uL8bbsS7KBxZ_NQJVYeakOdYtlkyr7Nis1JzNK9r7-whxqXpoIXFnb3rPktJ3di6QlugVeraQvKX4nVkZdUo",
#                "width" : 843
#             }
#          ],
#          "place_id" : "ChIJby4fFJQLThARkL3ls9hrLrY",
#          "rating" : 4.8,
#          "reference" : "ChIJby4fFJQLThARkL3ls9hrLrY",
#          "types" :
#          [
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 206
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Franca Afegbua Cres, Gudu, Abuja 900110, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 8.999581899999999,
#                "lng" : 7.481546000000001
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.000907029892721,
#                   "lng" : 7.483106829892722
#                },
#                "southwest" :
#                {
#                   "lat" : 8.998207370107277,
#                   "lng" : 7.480407170107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Evenanaspa and salon",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 639,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/113078568762075196621\"\u003eEvenanaspa and salon\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU6KT6IU8RcEw_fVXpEK69T_eraehb4MTo5tvMc-BeRXK9s-HUnmyEH9lKDS7M9KfHNtJ3WX51x4AFt3r5JcoQySsrnaMWjH_RlpI15bj90qsL_bgl7zXixWHh_50Aazf7L2VhyJM7_9kdfI_8tSYMZ8aNqricbTm1V3yCfPSaCgDtKOEqoQy6JyKAfPVa8vrHePpjQ0GTGpnxLm3a2eBMws2ClVMB2x1cIxO3m8WVFfwyFVOvqOPv9M6EGvUOTgIaiyQwf2sGDf-ibi7UTT9s_aF3V2_sSjw8d_cp1e5fCpbnf1YIo",
#                "width" : 1920
#             }
#          ],
#          "place_id" : "ChIJfclhHlwNThARqiXwDbDSIuQ",
#          "rating" : 4.7,
#          "reference" : "ChIJfclhHlwNThARqiXwDbDSIuQ",
#          "types" :
#          [
#             "beauty_salon",
#             "spa",
#             "hair_care",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 29
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Area 10, Bolingo Xperia Hotel and Towers, 777 Independence Ave, Municipal, Garki, Abuja 901002, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.0444216,
#                "lng" : 7.4793657
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.045655179892723,
#                   "lng" : 7.480788779892719
#                },
#                "southwest" :
#                {
#                   "lat" : 9.042955520107279,
#                   "lng" : 7.478089120107275
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Patty's beauty spa",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1183,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/108579265541228768686\"\u003ePatty&#39;s beauty spa\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU5f_Ks_4jtBfqpqUeNEh182f0xS_Cl4WrkkmD3_cwMFQEJtpHwNdk9tDhWYQD3bI9N6CYpchF1ITAwRO4AfrJ7r3x8H7j3xPwG0sGwF7vc52hE4Kf0Zj5PoMe79OGDWSAzUgQhByZKb-ylpN-fAEPsXUbO13D2yoP-w6UFz4XyjtT2GKLG22EReACpVZxjbSk9I8QzoGE0GRUgSAQNU58rHqSVJ5P8mLKri9q068AjhRGZBciOivixVb-DjvQxFZaq_8T6cChDaM7DlV88-JzoI-gF8nKPCeo_EKr980P7e4S-P73c",
#                "width" : 2100
#             }
#          ],
#          "place_id" : "ChIJMVNyj_YLThARTrSPnghz6og",
#          "rating" : 4.9,
#          "reference" : "ChIJMVNyj_YLThARTrSPnghz6og",
#          "types" :
#          [
#             "spa",
#             "beauty_salon",
#             "hair_care",
#             "store",
#             "health",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 61
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Unnamed Road, Jabi, Abuja 900108, Federal Capital Territory, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.082288999999999,
#                "lng" : 7.4310572
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.083623629892722,
#                   "lng" : 7.432417329892723
#                },
#                "southwest" :
#                {
#                   "lat" : 9.080923970107278,
#                   "lng" : 7.429717670107279
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "SB Hair Treatment Saloon",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 1008,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103703999818344089814\"\u003eSB Hair Treatment Saloon\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU4Xyv5EsiY1HuWq4sv7M5yiiUKHsZmwVC6siWll_94vAfbyO177-fNNXNY6tL7fjoOeu7k5FkqWmfBjBkS4UQ1ia8Ka9UaYw6-lJEbI-SCA5Cle7pgEdIyxTu6l-nw00bpmCUlJpbsI1w51fFct_5k3z9091AjxCtAsvI_m6NKUBWzwItRLUuAPjsJo6Qc-EkbG40Gx--N3b2acmTpatiuZRF3211WIrQSJ_fhY0otzEMNdQOeYPq3AfUdDlqFpmXm7cV7MmUR1MpgY9Deh_OM_R1vwmHjmNhpsTu0xxbLNo9Yu",
#                "width" : 490
#             }
#          ],
#          "place_id" : "ChIJX8gI3p51ThARQr5wBSw1KmU",
#          "rating" : 4.5,
#          "reference" : "ChIJX8gI3p51ThARQr5wBSw1KmU",
#          "types" :
#          [
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 44
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "No. 2 AB Close, 1st Avenue, Gwarinpa Estate, Abuja 900108, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 9.1031493,
#                "lng" : 7.416119999999999
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 9.104427979892723,
#                   "lng" : 7.41746032989272
#                },
#                "southwest" :
#                {
#                   "lat" : 9.101728320107279,
#                   "lng" : 7.414760670107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Fara Beauty Shop",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1280,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/110232598842639148596\"\u003eFara Beauty Shop\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU4eOUI2IcwoVGm1Te8hh93-AujQHvcsijKxFoP0jx6U84YIaEgoprofc5QCOGJSL04JHl_QbpQzsMJVd7IhYtCSfafwoyGr5gzkVDmAn6RDlYXjcrczF76SLNT0b8GtcLKilzwFh3QcOr6nBMrKdQrvIkFIMGZ1kf-_vDWCfGIKdJaSOROI1DyDM1c7htpceftblyliNHtyUOaQ139I2dbjXa76Yy6mX-YjINENsPfdg0u3e-bPZTsqlNm6vBf4Pb_RQKovYJrTP-Gwj5vmHrMrv3-vvlwLbYYmHHpjZj_r7-7QMUU",
#                "width" : 1280
#             }
#          ],
#          "place_id" : "ChIJHRQ2yp91ThARKIMpHpbvB94",
#          "rating" : 4.5,
#          "reference" : "ChIJHRQ2yp91ThARKIMpHpbvB94",
#          "types" :
#          [
#             "beauty_salon",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 25
#       }
#    ],
#    "status" : "OK"
# }
