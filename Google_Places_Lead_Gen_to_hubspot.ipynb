# %%
# %pip install requests pandas tqdm python-dotenv

import os
from dotenv import load_dotenv
import requests
import pandas as pd
from tqdm import tqdm
import time

# Load .env from project root (adjust path if needed)
load_dotenv(r"c:\Users\DELL\Downloads\Revops Code\RevOps_Analytics_portfolio\.env")

# --- CONFIG ---
API_KEY = os.getenv("GOOGLE_API_KEY")  # loaded from .env
if not API_KEY:
    raise RuntimeError("GOOGLE_API_KEY not found in environment. Add it to the .env file.")

MAX_RESULTS = 150 # Set the maximum number of results you want to retrieve

# --- INPUTS ---
keyword = input("Enter business type (e.g. 'dentist', 'restaurant', 'marketing agency'): ")
location = input("Enter location (e.g. 'Ikeja Lagos', 'Abuja', 'Port Harcourt'): ")
radius = 10000  # meters

# --- PHASE 1: BASIC PLACE SEARCH WITH PAGINATION ---
search_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={keyword}+in+{location}&radius={radius}&key={API_KEY}"
all_places = []
next_page_token = None

while len(all_places) < MAX_RESULTS:
    if next_page_token:
        search_url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?pagetoken={next_page_token}&key={API_KEY}"
    elif all_places: # Only request first page once
      break # Exit loop if no next_page_token and not the first page


    response = requests.get(search_url)
    data = response.json()

    places = data.get("results", [])
    all_places.extend(places)
    print(f"✅ Found {len(places)} results in this page. Total results: {len(all_places)}")

    next_page_token = data.get("next_page_token")

    if not next_page_token or len(places) == 0:
        break
    time.sleep(2) # Add a delay to avoid rate limiting

print(f"✅ Finished collecting initial results. Total results: {len(all_places)}")

# --- PHASE 2: PLACE DETAILS ENRICHMENT ---
details_url = "https://maps.googleapis.com/maps/api/place/details/json"
enriched_data = []

# Limit the number of places to process based on MAX_RESULTS
places_to_process = all_places[:MAX_RESULTS]


for place in tqdm(places_to_process, desc="Enriching leads"):
    place_id = place.get("place_id")
    params = {
        "place_id": place_id,
        "fields": "name,formatted_address,formatted_phone_number,website,rating,opening_hours,geometry",
        "key": API_KEY
    }
    details_resp = requests.get(details_url, params=params).json()
    details = details_resp.get("result", {})

    enriched_data.append({
        "Name": details.get("name"),
        "Address": details.get("formatted_address"),
        "Phone": details.get("formatted_phone_number"),
        "Website": details.get("website"),
        "Rating": details.get("rating"),
        "Open_Now": details.get("opening_hours", {}).get("open_now") if details.get("opening_hours") else None,
        "Maps_URL": f"https://www.google.com/maps/place/?q=place_id:{place_id}",
        "Location": location # Add the location to the DataFrame
    })

df = pd.DataFrame(enriched_data)

# --- EXPORT ---
file_name = f"{keyword}_{location}_enriched_leads.csv".replace(" ", "_")
df.to_csv(file_name, index=False)

print(f"💾 Exported {len(df)} enriched leads to '{file_name}'")
# Out:
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: python-dotenv in c:\users\dell\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# ✅ Found 20 results in this page. Total results: 20
# ✅ Found 20 results in this page. Total results: 20
# ✅ Found 20 results in this page. Total results: 40
# ✅ Found 20 results in this page. Total results: 40
# ✅ Found 20 results in this page. Total results: 60
# ✅ Finished collecting initial results. Total results: 60
# ✅ Found 20 results in this page. Total results: 60
# ✅ Finished collecting initial results. Total results: 60
# Enriching leads: 100%|██████████| 60/60 [00:36<00:00,  1.64it/s]
# 💾 Exported 60 enriched leads to 'supermarket_yaba_enriched_leads.csv'

# %%
import requests
import time
import pandas as pd
from datetime import datetime
import os
from dotenv import load_dotenv

# Load .env (if notebook restarted independently)
load_dotenv(r"c:\Users\DELL\Downloads\Revops Code\RevOps_Analytics_portfolio\.env")

# === HUBSPOT CONFIGURATION ===
HUBSPOT_API_KEY = os.getenv("HUBSPOT_API_KEY")  # loaded from .env
if not HUBSPOT_API_KEY:
    raise RuntimeError("HUBSPOT_API_KEY not found in environment. Add it to the .env file.")
BASE_URL = "https://api.hubapi.com"
COMPANY_URL = f"{BASE_URL}/crm/v3/objects/companies"

headers = {
    "Authorization": f"Bearer {HUBSPOT_API_KEY}",
    "Content-Type": "application/json"
}

# === FUNCTION: CHECK IF COMPANY EXISTS ===
def company_exists(domain=None, name=None):
    """Checks HubSpot for existing company by domain or name."""
    search_url = f"{BASE_URL}/crm/v3/objects/companies/search"
    filters = []

    if domain:
        filters.append({"propertyName": "domain", "operator": "EQ", "value": domain})
    if name and not domain:
        filters.append({"propertyName": "name", "operator": "EQ", "value": name})

    if not filters:
        return False

    payload = {"filterGroups": [{"filters": filters}]}
    resp = requests.post(search_url, headers=headers, json=payload)

    if resp.status_code != 200:
        print(f"⚠️ Search error for {name}: {resp.text}")
        return False

    results = resp.json().get("results", [])
    return len(results) > 0


# === FUNCTION: CREATE COMPANY ===
def create_company(row):
    """Creates company in HubSpot if not already existing."""
    if company_exists(domain=row["Website"], name=row["Name"]):
        return {"Name": row["Name"], "Status": "Duplicate", "Timestamp": datetime.now()}

    data = {
        "properties": {
            "name": row["Name"],
            "address": row["Address"],
            "phone": row["Phone"] or "",
            "domain": row["Website"] if row["Website"] else "",
            "city": row["Location"],
            # Removed the 'source' property as it caused an error
        }
    }

    response = requests.post(COMPANY_URL, headers=headers, json=data)

    if response.status_code == 201:
        print(f"✅ Added company: {row['Name']}")
        return {"Name": row["Name"], "Status": "Added", "Timestamp": datetime.now()}
    else:
        print(f"❌ Failed for {row['Name']}: {response.text}")
        return {"Name": row["Name"], "Status": "Failed", "Timestamp": datetime.now()}


# === LOOP THROUGH LEADS AND PUSH TO HUBSPOT ===
sync_log = []

for i, row in df.iterrows():
    result = create_company(row)
    sync_log.append(result)
    time.sleep(0.3)  # Prevent API rate limit issues

# === EXPORT SYNC LOG ===
log_df = pd.DataFrame(sync_log)
log_file_name = f"company_sync_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
log_df.to_csv(log_file_name, index=False)

print(f"📊 Sync Log saved as {log_file_name}")
# Out:
# ✅ Added company: Mallmart Supermarket
# ✅ Added company: HANDY BASKET SUPERSTORE
# ✅ Added company: HANDY BASKET SUPERSTORE
# ✅ Added company: LAIT STORES
# ✅ Added company: LAIT STORES
# ✅ Added company: Tonyson Pharmacy and Stores
# ✅ Added company: Tonyson Pharmacy and Stores
# ✅ Added company: D-ARENA SUPERMARKET YABA
# ✅ Added company: D-ARENA SUPERMARKET YABA
# ✅ Added company: QMART SUPERMARKET
# ✅ Added company: QMART SUPERMARKET
# ✅ Added company: Melody Supermarket
# ✅ Added company: Melody Supermarket
# ✅ Added company: Lifeback Pharmacy and Store Limited
# ✅ Added company: Lifeback Pharmacy and Store Limited
# ✅ Added company: Addide Iwaya
# ✅ Added company: Addide Iwaya
# ✅ Added company: Staplestores
# ✅ Added company: Staplestores
# ✅ Added company: Yem-Yem Superstores LUTH
# ✅ Added company: Yem-Yem Superstores LUTH
# ✅ Added company: Bokku! Mart Herbert Macaulay way, Yaba
# ✅ Added company: Bokku! Mart Herbert Macaulay way, Yaba
# ✅ Added company: Megaland Supermarket
# ✅ Added company: Megaland Supermarket
# ✅ Added company: ONYITEX Supermarket
# ✅ Added company: ONYITEX Supermarket
# ✅ Added company: Seamon Supermarket
# ✅ Added company: Seamon Supermarket
# ✅ Added company: ONUWA SUPERSTORE
# ✅ Added company: ONUWA SUPERSTORE
# ✅ Added company: I Y International Store
# ✅ Added company: I Y International Store
# ✅ Added company: Agape Super Store
# ✅ Added company: Agape Super Store
# ✅ Added company: Tokio Supermarkets
# ✅ Added company: Tokio Supermarkets
# ✅ Added company: The Ozone e-centre tsboi
# ✅ Added company: The Ozone e-centre tsboi
# ✅ Added company: Tejuosho Shopping Center
# ✅ Added company: Tejuosho Shopping Center
# ✅ Added company: Bokku! Mart, Owodunni, Iwaya, Yaba
# ✅ Added company: Bokku! Mart, Owodunni, Iwaya, Yaba
# ✅ Added company: Emperor Superstores
# ✅ Added company: Emperor Superstores
# ✅ Added company: Temple Hill Supermarket Discounts Centre
# ✅ Added company: Temple Hill Supermarket Discounts Centre
# ✅ Added company: Citydia Supermarket
# ✅ Added company: Citydia Supermarket
# ✅ Added company: Hubmart
# ✅ Added company: Hubmart
# ✅ Added company: Biobaku Mini Supermarket
# ✅ Added company: Biobaku Mini Supermarket
# ✅ Added company: Tejuosho Market Yaba Lagos
# ✅ Added company: Tejuosho Market Yaba Lagos
# ✅ Added company: Eazistock Groceries
# ✅ Added company: Eazistock Groceries
# ✅ Added company: Chioma Supermarket
# ✅ Added company: Chioma Supermarket
# ✅ Added company: Jendol Superstores Egbeda
# ✅ Added company: Jendol Superstores Egbeda
# ✅ Added company: Happy World Store
# ✅ Added company: Happy World Store
# ✅ Added company: Home affairs supermarket Ogudu
# ✅ Added company: Home affairs supermarket Ogudu
# ✅ Added company: Grace Flow 2 Supermarket
# ✅ Added company: Grace Flow 2 Supermarket
# ✅ Added company: Chuqmanda Pharmacy & Supermarket
# ✅ Added company: Chuqmanda Pharmacy & Supermarket
# ✅ Added company: Mattoris supermarket
# ✅ Added company: Mattoris supermarket
# ✅ Added company: A - Z Supermarket
# ✅ Added company: A - Z Supermarket
# ✅ Added company: Romero Superstore
# ✅ Added company: Romero Superstore
# ✅ Added company: Chidi Venture
# ✅ Added company: Chidi Venture
# ✅ Added company: The Palmas Place
# ✅ Added company: The Palmas Place
# ✅ Added company: N-great Glory Supermarket
# ✅ Added company: N-great Glory Supermarket
# ✅ Added company: Supersaver Supermarket
# ✅ Added company: Supersaver Supermarket
# ✅ Added company: Obi Foundation Supermarket
# ✅ Added company: Obi Foundation Supermarket
# ✅ Added company: Yaba market
# ✅ Added company: Yaba market
# ✅ Added company: Fuznaq Store
# ✅ Added company: Fuznaq Store
# ✅ Added company: THE MART
# ✅ Added company: THE MART
# ✅ Added company: Lyquids
# ✅ Added company: Lyquids
# ✅ Added company: Prince Ebeano Supermarket
# ✅ Added company: Prince Ebeano Supermarket
# ✅ Added company: Supersaver Supermarket
# ✅ Added company: Supersaver Supermarket
# ✅ Added company: Mrs Temitayo Store
# ✅ Added company: Mrs Temitayo Store
# ✅ Added company: IG Supermarket
# ✅ Added company: IG Supermarket
# 📊 Sync Log saved as company_sync_log_20251026_170225.csv
# 📊 Sync Log saved as company_sync_log_20251026_170225.csv

# %%
print(response.status_code, response.text)
# Out:
# 200 {
#    "html_attributions" : [],
#    "results" :
#    [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "21 Oshodi Rd, Mafoluku Oshodi, Lagos 102214, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.556146099999999,
#                "lng" : 3.3489553
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.55757587989272,
#                   "lng" : 3.350309379892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.554876220107277,
#                   "lng" : 3.347609720107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Adeyeye Supermarket",
#          "photos" :
#          [
#             {
#                "height" : 1080,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/106838315722492586148\"\u003eAbdulmalik Saleh\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7k0u7kwG4IHREamin8W72YiyaRrkw44Wu222Sm44YraxhA1w-Rm_MgoUXwnqILkn9g34SiKZdtwpO8YlsJGiGnwKbtRwDrWw92tf-LxGwbS3xyA1QmuCdD1eo0NMKw_UPVDfyaJcFIpRfIq8H8utzHMTCFaZeLJJYo_iyYUMZoliGZ8b_ljeQUmNHbJTlEpQoafj1ccvezoGudbSto4qMqCjAK5qcaZxGbonHB-qED7hctJDH6YBMS6UpOnBqVLZ1qQDEzniYrQ4vTMOby_YYOoVRrAPSFNL96JmUyUtjTAmHV1JGw_PkrsGNRhJbIH28Ywkx4g-OR1-FASleUQlGZDI09iQ_cEAmkTAUMFgdtzqMZqoiutX5CHizB5BnOAfdw0ei2m4r8oEEH-LbuBQZPWqGLGFOu9cgnyjnwl_gFwDdmAQi0dj5LZMT_zLddUqKh_lZIVtwJus8mLKBXqEvUi5UupWtqQhrlssIE5Z7nR1QykvtmVWqyalGY_JavRRvV26oi3yHQTeDsFKnGQqyuxTVbgfx5IR34dSAxNgGzHaCOjXztquQeeD4MHseal6ossAT6",
#                "width" : 811
#             }
#          ],
#          "place_id" : "ChIJv1bYo_6NOxARO09KPFECSfk",
#          "rating" : 4.3,
#          "reference" : "ChIJv1bYo_6NOxARO09KPFECSfk",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 3
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "72 Akerele Street Surulere, Lagos surulere akerele, Surulere, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.5047833,
#                "lng" : 3.3557803
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.506191729892722,
#                   "lng" : 3.357167679892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.503492070107278,
#                   "lng" : 3.354468020107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/pharmacy-71.png",
#          "icon_background_color" : "#F88181",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/pharmacy_pinlet",
#          "name" : "Healthrite Pharmacy & Supermart",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 4032,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/103457863905993382320\"\u003eHealthrite Pharmacy &amp; Supermart\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5S
u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7PUN0B_p2seSG6m42W_EVyTKMtSsJeoDGjINTI4rWUrrPeyJ00nTb4Csd_jwTMta66lfYC6WNK5gBU7OY9EqX5H5-itXw8GDP_jnUayVe-XR-GJEUoIJ_3tBuBg3j5Db9H8-_-l4VUiKYgfTUvukHngGd_rHGsl4AocuklqWvDzAAE-QVXw6DGy3cuQS-fV3Hiiqy6YThs-si9nPjHpLsNWGHpl4-cpb91CPhsPxu_iKS_aAJet39TR2lzuEmDBQMUMLUCCkrcQDMheIUd_Y9q10I99NRCJ6QclCu081JKtAg4y6A",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJ1RdI0qWNOxARMdY-mtF4PYY",
#          "rating" : 2.4,
#          "reference" : "ChIJ1RdI0qWNOxARMdY-mtF4PYY",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 5
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "14 Remilekun St, Surulere, Lagos 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.508308899999999,
#                "lng" : 3.3537549
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.509713829892722,
#                   "lng" : 3.355107279892723
#                },
#                "southwest" :
#                {
#                   "lat" : 6.507014170107278,
#                   "lng" : 3.352407620107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Chi-Tina Supermarket",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 4000,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/111226029682164067534\"\u003eFarouk Ade\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU4f3jm5dbQ8_ppc6NCvPtHcY9rb2F7gJRCIv-Dj36ySNB_671zbksFQifqPcMKzj3mJSi1VQWxj_Bh-mDQEBVTt6atw5BeoRhY_IAJUjA-jL8HGoMPgSwr7En-0vSPJCGfSBp0SkB2zFUsq9Em6W1-tyhtepfB-9f31Ea5k7rMED2XrFdrb9DIHvsMv7Q27SkFKU8tHrZVNYxyAjUPR4qD7R815lcCpCeO25FU-TLSLylc3B9sOTJ0666DO77yakZXpyKf_kpvaA4MAhlUpqW_UUCbA9a_O6QhzA33UY6ArT3D-9hBYwTbPKDb5Hs8lQIqdfj7IFnsP35CvBViqX066Rfgt84K7sqKJt8HuA591rkdWPsq3Ojb0QZ6qOj5svtYGSUBuw1i3mOPr9bx-7WISWakfBZfw4YmXUSMhMJzIF8YmIbkNM-4iz9UgSEOL_73t8jno4EXc3tQPTRrt5_IjQDKrXJuv2yZff3Z7WZ7AFnUpQFCWb2tUYJg3iJkKDhpCLsc9IH1_V6SFa1sFYuLsXXkjgqI1vmWii-GvEO3qWcS3B1UGDorlZtzze6VM2QbTYw",
#                "width" : 2250
#             }
#          ],
#          "place_id" : "ChIJwaTuwraNOxARUISwIeVAOgM",
#          "rating" : 4.2,
#          "reference" : "ChIJwaTuwraNOxARUISwIeVAOgM",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 192
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "8 Benson St, Ajegunle, Lagos 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.5037669,
#                "lng" : 3.3588032
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.505133629892722,
#                   "lng" : 3.360119179892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.502433970107278,
#                   "lng" : 3.357419520107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Chibon SUPERMARKET",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1080,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101192973671716177614\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU400BFLK4o75QGM1J2HYHwZ_mGhUiAnw31RVxuwR9U2hdruV7zIDWNZWcLIVLTu6ngHPXouwuuQHPRBSMg6o5Ryxe-jFs5FANZARTx8_6E4w_h-c_s9Vc-YyF6kwox02wtRuw9pRo8fLEcH28u_kxHkR6Bik7ssG1fRRixXEsefKX5ja7i30e3WWmYFcN8qS1Rp1fs0jrhYW3mZi02BAeh704ciy75CBQ50HwqORp-849IjiYY2M8aqdlqJKYEP17Rb2yDbnzzX7jV8b6xqjau5XH97RsM7cYxaZd1GuECblOa4smg",
#                "width" : 1920
#             }
#          ],
#          "place_id" : "ChIJSYjbyb-NOxARF9HvxvSF1Uc",
#          "rating" : 4,
#          "reference" : "ChIJSYjbyb-NOxARF9HvxvSF1Uc",
#          "types" :
#          [
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" :

#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJS-jEOviSOxARd0GvegYesYE",
#          "rating" : 4.1,
#          "reference" : "ChIJS-jEOviSOxARd0GvegYesYE",
#          "types" :
#          [
#             "grocery_or_supermarket",
#             "liquor_store",
#             "supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 2117
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "1Chief Natufe Street, Surulere, Lagos 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.4879758,
#                "lng" : 3.3482769
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.489232379892722,
#                   "lng" : 3.349649779892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.486532720107278,
#                   "lng" : 3.346950120107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Goldchase supermarket",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 4032,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102356042208997789693\"\u003eOluwashile Adeniyi\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7TcRuZcJP-GJ-GO0XMJmcz8fCCf1ttpYf5h1TabpjeD7omJtsZ7l5V_GJYXnk0lYGcM3l0Kvu8ha3M8Qm8lyEjl-izn1a629PasTUXCLQzVetuuddv8ZugMsf3RVPzXWF8L65sp8xV_1zAh-Im5aZuKW8UznyXdkZfI9lgPPKP-AX2yLhDydvD9iGGDpWl4suTfXQNpzBXA_eCZgw_81pC63PPBsEEZQgwMCiYzzAWtzXmZ5Vll1hZWwu3gfxPkqrmI2MlpAbsvbV6wpLhB-gxM6iagJsSZ6cYdUxeaL4r5MXOGrARhhyCqDmHo5tFtWb5EMtVVQv7utcM1naQus-XQZmoxERBT2xLPy0dWl4PL71jnECRR629UDHH_kio_8mjPSxI7o0wVJ51E3Bu-6vSxTPmOZBbb-fU_k_d0pMD4nXwqhGExcTl_h4bYbOPopc1ZLhEVNt9_09V7TrSX5ma80xs8VXpxVk-pTAV8mhhL375F0QB3r3unQK3UE5uNmWUZNydItjCLLl3NLrIdb1nfXj2rF1B8crdfsfb3jq50AWJmQrW1uNTT6CmlJGUy5Q5DQ",
#                "width" : 3024
#             }
#          ],
#          "place_id" : "ChIJE_CglTuNOxARy-4HM98Ds8Y",
#          "rating" : 3.8,
#          "reference" : "ChIJE_CglTuNOxARy-4HM98Ds8Y",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 5
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "12 Adetola St, Surulere, Lagos 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.4952162,
#                "lng" : 3.3391757
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.496514179892722,
#                   "lng" : 3.340644529892723
#                },
#                "southwest" :
#                {
#                   "lat" : 6.493814520107278,
#                   "lng" : 3.337944870107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Tony Vegas Supermarket",
#          "place_id" : "ChIJp3H2Rz2NOxARlEqGJGDfA7g",
#          "rating" : 5,
#          "reference" : "ChIJp3H2Rz2NOxARlEqGJGDfA7g",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 1
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "40 Ijesha Rd, Itire, Lagos 102215, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.508658899999999,
#                "lng" : 3.3360069
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.510026129892723,
#                   "lng" : 3.337345279892723
#                },
#                "southwest" :
#                {
#                   "lat" : 6.507326470107279,
#                   "lng" : 3.334645620107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Downtown Supermarket",
#          "place_id" : "ChIJSezeKZyOOxARyDo8XV41B7Q",
#          "rating" : 4.5,
#          "reference" : "ChIJSezeKZyOOxARyDo8XV41B7Q",
#          "types" :
#          [
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 2
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "kilo bus stop, 4 Akpoguma St, Surulere, 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.5009103,
#                "lng" : 3.3455231
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.502367829892721,
#                   "lng" : 3.346859829892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.499668170107277,
#                   "lng" : 3.344160170107277
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Bokku! Mart Akpoguma Street, Surulere",
#          "opening_hours" :
#          {
#             "open_now" : true
#          },
#          "photos" :
#          [
#             {
#                "height" : 1280,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116333589587249842855\"\u003eBokku! Mart Akpoguma\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7G0BZR3Q-gLfV-UkXURUE6UWsMvf6IHgSxYvYW7S9X2uajsco1Q3yDOzbMn2u4Fo0vUhDeww4yUPVI4ZAo_v_6EvAr_Y9uu9y7UxbdN_pTupFGoK2OlhnKuSKheNgKXAwCRGMH2lnCjUVJ7REIchSQ0SUDLQlvsHv4wPJfExGpJq2Y6yGpur_f5Awv1e4JwOyJu_Cp5x3bRfDSWkmKecwbnk5_LCUy6jp-ybq3it0mIMBHZqyeKEqc5sG8uWNGJeLJ8SJLEjgCJMyXFbMOnLVWkIJS0QnNOlOXCR5I1-VJhjUHWuo",
#                "width" : 960
#             }
#          ],
#          "place_id" : "ChIJrQFNMgCNOxARYpQwQEXNjJA",
#          "reference" : "ChIJrQFNMgCNOxARYpQwQEXNjJA",
#          "types" :
#          [
#             "supermarket",
#             "grocery_or_supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ]
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "15 Yesufu Sanusi St, Surulere, Lagos 101241, Lagos, Nigeria",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 6.4954645,
#                "lng" : 3.3587081
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 6.496822329892722,
#                   "lng" : 3.360173379892722
#                },
#                "southwest" :
#                {
#                   "lat" : 6.494122670107278,
#                   "lng" : 3.357473720107278
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png",
#          "icon_background_color" : "#4B96F3",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet",
#          "name" : "Ego Supermarket",
#          "opening_hours" :
#          {
#             "open_now" : false
#          },
#          "photos" :
#          [
#             {
#                "height" : 3024,
#                "html_attributions" :
#                [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/116978919133771692224\"\u003eEgo Supermarket\u003c/a\u003e"
#                ],
#                "photo_reference" : "AWn5SU7X7Ef8EBxXitS3XH9qWVHsoT6qzLk_-5Om_CVceo5CFsbI7MlqWt1JF08gT2jsg4BYIiRTHxfaKQ3yPZEMMz89tQaDoapI-yC2IW8r2nvdyPS-8ufsbBDTg3Xiss_y-FPP7BaJa0uh5iqYZij2g4jmC4Q3offT7WejxXiRWaeTfP_DUwDjsVgf9u04XhtVLYqNUAZtRV9qTamyAShfP4Poe3i8_ZpiOg1wO-lNIA95TG03844XlwYqpZ3G3isUQJ74N_3JfsUoDbN3k0V-JQSwSZf2vc93TcEo-KCk18HfRAHcV0E",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJkaRhKROMOxARLh3e3WHZ4Ao",
#          "rating" : 4.5,
#          "reference" : "ChIJkaRhKROMOxARLh3e3WHZ4Ao",
#          "types" :
#          [
#             "grocery_or_supermarket",
#             "supermarket",
#             "point_of_interest",
#             "store",
#             "food",
#             "establishment"
#          ],
#          "user_ratings_total" : 32
#       }
#    ],
#    "status" : "OK"
# }
